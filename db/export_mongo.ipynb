# %%
import os
from pymongo import MongoClient
import json
import pandas as pd
import dotenv
from datetime import datetime
import subprocess

# %%
dotenv.load_dotenv()

USER = os.getenv("MONGO_USER")
PASSWORD = os.getenv("MONGO_PWD")
DATABASE = os.getenv("MONGO_DB")
COLLECTION = "LEARNERS"

ATLAS_URI = f"mongodb+srv://{USER}:{PASSWORD}@cluster0.0nlbhko.mongodb.net/?retryWrites=true&w=majority"
mongo_client=MongoClient(ATLAS_URI)
collection = mongo_client[DATABASE][COLLECTION]


cursor = collection.find({})

df = pd.DataFrame(cursor)
df
# Out:
#                             _id      user_name  \
# 0     0d6548NUcprmyg45brzZZ8468     godasamiha
# 1     0b6376XOfmshzm18lmmTZ3501         owagle
# 2    3od2539RScpavnv74txxOS3039          mdyal
# 3    7xd7613QVgmpcqk64lvsDT2667      golahiran
# 4     7a5190DTajhbjm57yzbTQ4758  zachariasahil
# ..                          ...            ...
# 195  3ux1974TYykkowv54wbeXY5293        mthomas
# 196  0bu1437CUqaltbb71oaqEE4863     samantha60
# 197  7sa9094FZctijmr16helWM2398    amandabowen
# 198  3ux6986IStrxenx68nrwZZ7164         zsmith
# 199  0zc9962VNjuwyda21vpfZW6471  karenphillips
#
#                               email_id            signin_dt first_name  \
# 0        jivika.chowdhury@seesight.com  2022-12-18 18:14:08     Jivika
# 1          dishani.choudhry@example.in  2021-11-24 07:30:02    Dishani
# 2              renee.mane@bluevice.com  2022-02-15 15:19:04      Renee
# 3          rati.seth373@yellowstone.in  2021-08-09 11:32:05       Rati
# ...

# %%
df.to_json(f"./data/exported-on-{datetime.now().date().strftime('%Y-%m-%d')}.json", index=False)

# %%
datetime.now().date().strftime('%Y-%m-%d')
# Out:
# '2024-01-29'

# %%
# check

import json

with open('./data/exported-on-2024-01-29.json', 'r') as json_file:
    exported_check_data = json.load(json_file)
# Out:
# dict_keys(['_id', 'user_name', 'email_id', 'signin_dt', 'first_name', 'last_name', 'age', 'mobile', 'address', 'country', 'profession', 'field_of_interest', 'reason_of_enrollment', 'is_verified', 'verification_type', 'verification_id', 'courses'])

# %%
exported_check_data.keys()
# Out:
# dict_keys(['_id', 'user_name', 'email_id', 'signin_dt', 'first_name', 'last_name', 'age', 'mobile', 'address', 'country', 'profession', 'field_of_interest', 'reason_of_enrollment', 'is_verified', 'verification_type', 'verification_id', 'courses'])

# %%
for i in exported_check_data.keys():
    print(f"{i}:",exported_check_data[i]['100'])
# Out:
# _id: 7ub1805ZRdavlgw31omhRN9531
# user_name: lopezangela
# email_id: john.howard26@example.in
# signin_dt: 2021-06-18 01:41:50
# first_name: John
# last_name: Howard
# age: 47
# mobile: +1-126-561-4115
# address: 95872 Vanessa Wells Apt. 839,Port Emily, LA,64238
# country: USA
# profession: businessman
# field_of_interest: IT
# reason_of_enrollment: self-improvement
# is_verified: yes
# verification_type: SSN
# verification_id: 070-22-7803
# ...

# %%
file_path = f"./data/exported-on-{datetime.now().date().strftime('%Y-%m-%d')}.json"

with open(file_path, 'w') as empty_file:
    pass

for record in collection.find({}):
    with open(file_path, 'a') as j:
        json.dump(record,j, indent=4)

# %%
with open(f"./data/exported-on-{datetime.now().date().strftime('%Y-%m-%d')}.json",'w') as jf:
    json.dump(list(collection.find({})), jf, indent=4)
